# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json
import os

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("twin/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# 5408248763 (Home)
# dhanushndinesh@gmail.com
# www.linkedin.com/in/dhnd
# (LinkedIn)
# bit.ly/dnd_res (Personal)
# github.com/dhanushnd101
# (Portfolio)
# Top Skills
# Oracle Database
# Spring Framework
# Database Management System
# (DBMS)
# Languages
# Kannada (Native or Bilingual)
# Hindi (Professional Working)
# English (Full Professional)
# Certifications
# machine learning data science and
# Deep learning with Python
# The Data Science Course 2020:
# Complete Data Science Bootcamp
# AWS Certified Solutions Architect –
# Associate
# Publications
# Speech Recognition System Using
# Deep Neural Network
# Experimental Analysis of
# Performance Metrics for
# Configuration of Auto Scaling
# Groups
# Dhanush Dinesh
# AVP, Sr. DevOps Engineer @ Citi | DevOps, Automation, Cloud |
# AWS Certified Solutions Architect – Associate
# Irving, Texas, United States
# Summary
# As a Sr. DevOps Engineer, Assistant Vice President at Citi, I work
# on building applications and creating infrastructure to deploy them as
# docker containers. I use my skills in Amazon Web Services (AWS) to
# automate many CI-CD processes and orchestrate various services
# using knowledge graphs and Kubernetes. I enjoy working on the
# latest cloud computing platforms and delivering reliable and robust
# solutions for the financial industry.
# Before joining Citi, I completed my Master of Engineering in
# Computer Engineering from Virginia Tech, where I also worked as
# a graduate teaching and research assistant. I was involved in a
# project to index around 4 million electronic theses and dissertations
# using a web application that I built with a lightweight docker image. I
# also published two research papers on using speech as instructions
# for web-based services and on integrating auto-scaling groups
# in the cloud infrastructure. I am passionate about learning new
# technologies and applying them to real-world problems.
# Experience
# Citi
# Sr. DevOps Engineer, Assistant Vice President
# May 2023 - Present (3 years 3 months)
# Irving, Texas, United States
# • Maintained Zephyr Enterprise and automated deployments using Ansible &
# Jenkins for 5,000 users
# • Created a Python script to migrate test cases from Jira Squad, reducing
# manual effort by 900 hours
# • Worked on creating microservices to onboard our users using Spring Boot
# and deployed these services in OpenShift using Docker image
# • Automated removal of legacy custom fields by converting them into tags,
# eliminating 30M+ database rows and improving application performance;
# saved 800 days of manual effort and $450,000 in operational costs
#   Page 1 of 3
# Virginia Tech College of Engineering
# 1 year 10 months
# Graduate Research
# May 2022 - May 2023 (1 year 1 month)
# • Built a lightweight docker image to host a web application to index around 4
# million ETDs
# • Used knowledge graph (DAGs) to interconnect various services we created
# by using Apache Airflow
# • The pipeline of the application was created by orchestration services in
# Kubernetes using Rancher
# Graduate Teaching Assistant
# August 2021 - May 2023 (1 year 10 months)
# Blacksburg, Virginia, United States
# GTA for Intermediate Physics course under Dr. Thomas O'Donnell
# GTA for Fundamentals of Digital Systems under Dr. Kristie Cooper
# GTA for Computer Vision ECE 5554 under Dr. Creed Jones
# Grading of Fundamentals of Digital Systems under Dr. Kristie Cooper
# Aurigo Software Technologies
# 1 year 8 months
# Software Engineer 1 - DevOps
# January 2021 - August 2021 (8 months)
# Bengaluru, Karnataka
# - Built a robust fully automated seamless deployment CI-CD pipeline to
# manage company’s websites
# - Developed an automated server connection system which helped eliminate
# 120hr of manual work every quarter
# - Devised scripts to automate the creation of load balancer, target group, take
# backups and migrated data from S3 which saved the company more than
# $200,000
# - Worked on amazon web service (AWS), azure devops as well as SQL server
# management studio
# Projects and Initiatives (Designed)
# • Application Copy Framework
# • Remote script execution using SSM
# • AzureDevOps Pipelines
# • Release Pipeline Framework
#   Page 2 of 3
# • Customized and flexible framework for Application Deployment using Azure
# Releases
# • Powershell script in backend
# • SonarQube deployment
# • Azure DevOps Release integrated
# • Migration of S3
# • Automation of service connections creation and updation
# Worked on integration of DevOps processes.
# Help build a robust fully automated seamless deployment pipeline.
# Managed many AWS, Azure and SSMS services.
# Intern Cloud Ops
# January 2020 - December 2020 (1 year)
# Bengaluru, Karnataka, India
# - Built a highly available, fault tolerant infrastructure on AWS
# - The infrastructure consist of multiple servers in multiple availability zones with
# the implementation of load balancing, auto scaling for higher reliability and web
# traffic management for a highly available web application
# - Worked as DataBase Administrator (DBA) and took care of DB servers
# Education
# Virginia Tech
# Master of Engineering, Computer Engineering · (August 2021 - May 2023)
# R. V. College of Engineering, Bangalore
# Bachelor's degree, Electrical, Electronics and Communications
# Engineering · (2016 - 2020)
#   Page 3 of 3

# %%
with open("twin/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
print(summary)
# Out:
# My name is Dhanush Dinesh. As a Sr. DevOps Engineer, Assistant Vice President at Citi,
# I work on building applications and creating infrastructure to deploy them as docker containers.
# I use my skills in Amazon Web Services (AWS) to automate many CI-CD processes and orchestrate
# various services using knowledge graphs and Kubernetes. I enjoy working on the latest cloud computing
# platforms and delivering reliable and robust solutions for the financial industry.
#
# Before joining Citi, I completed my Master of Engineering in Computer Engineering from Virginia Tech,
# where I also worked as a graduate teaching and research assistant. I was involved in a project to index
# around 4 million electronic theses and dissertations using a web application that I built with a lightweight docker image.
# I also published two research papers on using speech as instructions for web-based services and
# on integrating auto-scaling groups in the cloud infrastructure. I am passionate about learning new technologies and
# applying them to real-world problems.
#
# I'm originally from Bangalore, India, but I moved to Dallas in 2023.
# I love all foods, particularly Thai food, love some Indian food as well. My favoret dish is Dosa.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is DND"}
]

# %%
import os
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv('GOOGLE_API_KEY')
openai = OpenAI(api_key=google_api_key, base_url=GEMINI_BASE_URL)

model_name = "gemini-3.1-flash-lite"

# %%
response = openai.chat.completions.create(model=model_name, messages=messages)
print(response.choices[0].message.content)
# Out:
# Hi DND! It's nice to meet you. How can I help you today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is DND"}
]

# %%
response = openai.chat.completions.create(model=model_name, messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh, DND? Let me guess: you’re either an avid fan of imaginary dragons, or you’re someone who refuses to answer their phone.
#
# Either way, I’m thrilled to make your acquaintance. How can I assist you today, or are you just here to roll for initiative?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"},
    {"role": "assistant", "content": "Well hi there, Ed. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's LinkedIn profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
display(Markdown(response.choices[0].message.content))

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    return response.choices[0].message.content

# %%
chat("Please summarize who you are", [])

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("test@testy.com")

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>
